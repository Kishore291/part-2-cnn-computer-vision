# %%
import os
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

# Create required folders
os.makedirs('results', exist_ok=True)
os.makedirs('sample_predictions', exist_ok=True)

print("Loading Data...")
mnist = tf.keras.datasets.mnist
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# Preprocessing
X_train = X_train.reshape(-1, 28, 28, 1) / 255.0
X_test = X_test.reshape(-1, 28, 28, 1) / 255.0

print("Training Model (This will take ~60 seconds)...")
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(64, activation='relu'),
    Dense(10, activation='softmax')
])
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history = model.fit(X_train, y_train, epochs=3, validation_split=0.2, batch_size=64)

print("Saving Graphs...")
# 1. Accuracy/Loss
plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Val')
plt.title('Accuracy')
plt.legend()
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train')
plt.plot(history.history['val_loss'], label='Val')
plt.title('Loss')
plt.legend()
plt.savefig('results/accuracy_loss_curves.png')
plt.close()

# 2. Confusion Matrix
y_pred = np.argmax(model.predict(X_test, verbose=0), axis=1)
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.savefig('results/confusion_matrix.png')
plt.close()

# 3. Sample Predictions
plt.figure(figsize=(10, 5))
for i in range(10):
    plt.subplot(2, 5, i+1)
    plt.imshow(X_test[i].reshape(28, 28), cmap='gray')
    plt.title(f"T:{y_test[i]} | P:{y_pred[i]}", fontsize=10)
    plt.axis('off')
plt.savefig('sample_predictions/prediction_outputs.png')
plt.close()

print("DONE! Check sidebar to download.")
# Out:
# Loading Data...
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Training Model (This will take ~60 seconds)...
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/3
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 38s 45ms/step - accuracy: 0.9358 - loss: 0.2213 - val_accuracy: 0.9737 - val_loss: 0.0907
# Epoch 2/3
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 33s 34ms/step - accuracy: 0.9786 - loss: 0.0700 - val_accuracy: 0.9792 - val_loss: 0.0636
# Epoch 3/3
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 26s 34ms/step - accuracy: 0.9851 - loss: 0.0474 - val_accuracy: 0.9849 - val_loss: 0.0535
# Saving Graphs...
# DONE! Check sidebar to download.
